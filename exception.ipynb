# %%
def safe_div():
    try:
        a = int(input("Enter a number: "))
        b = int(input("Enter another number: "))
        print("The sum of the numbers is: ", a / b)
    except ValueError:
        print("Invalid input. Please enter a valid number.")
        safe_div()
    except ZeroDivisionError:
        print("Cannot divide by zero.")
        safe_div()

# %%
safe_div()
# Out:
# Cannot divide by zero.
# The sum of the numbers is:  0.0

# %%
try:
    a = int(input("Enter a number: "))
    b = int(input("Enter a number: "))
    print(a/b)
except Exception as e:
    print("Cannot divide by zero", e)
# Out:
# Cannot divide by zero division by zero

# %%
try:
    a = int(input("Enter a number: "))
    b = int(input("Enter a number: "))
    print(a/b)
except ZeroDivisionError:
    print("Cannot divide by zero")
except ValueError:
    print("Invalid input")
else:
    print("No errors")
finally:
    print("Program execution completed")
# Out:
# Cannot divide by zero
# Program execution completed

# %%
class AgeError(Exception):
    pass
age = int(input("Enter your age: "))
if age < 18:
    raise AgeError("Age is less than 18")
else:
    print("Age is valid")
# Out:
# Age is valid

# %%
# assertion error
s1 = input("Enter a string ")
s2 = input("Enter a string ")
assert len(s1) == len(s2), "Strings are not of same length"
print("Strings are of same length")
# Out:
# Strings are of same length

# %%
x = int(input("Enter a number: "))
assert x > 0, "Number should be positive"
print("Number is positive")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 x = int(input("Enter a number: "))
# ----> 2 assert x > 0, "Number should be positive"
#       3 print("Number is positive")
#
# AssertionError: Number should be positive
